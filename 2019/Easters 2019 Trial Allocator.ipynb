# %%
# Modules
import gurobipy as grb
import pandas as pd
import numpy as np
import math
import random

# Standard output divider
div = "-----"

# Print warning message


# Timeslots
alltimeslots = {
    1: "8:00am",
    2: "8:45am",
    3: "9:30am",
    4: "10:30am",
    5: "11:15am",
    6: "12:00pm",
    7: "1:15pm",
    8: "2:00pm",
    9: "2:45pm",
    10: "3:45pm",
    11: "4:30pm",
    12: "5:15pm",
    13: "6:30pm",
    14: "7:15pm",
    15: "8:00pm",
    16: "8:45pm"
}



# Dictionary of preference strings and corresponding values
preferencedict = {
    "Available, Prefer": 1,
    "Available, Neutral Preference": 2,
    "Available, Prefer Not": 3,
    "Unavailable": 4
}

# Dictionary of speaker vetos and corresponding values

vetodict = {
    "I would not like to veto any position": 0,
    "1st Speaker": 1,
    "2nd Speaker": 2,
    "3rd Speaker": 3,
}

vetodictinv = {
    0: "has no speaker position vetoes",
    1: "has vetoed 1st speaker",
    2: "has vetoed 2nd speaker",
    3: "has vetoed 3rd speaker"
}

# Person class
# - No preferences or vetoes for Easters trials

class person:
    name = ""
    
    # Speaker veto - 1 for 1st, 2 for 2nd, 3 for 3rd, 0 for no veto
    speakerveto = 0
    
    # Key-value pair for availability - Key is the slot
    # 1 = Prefer
    # 2 = Available
    # 3 = Prefer Not
    # 4 = Unavailable
    availabilities = {}
    
    def __init__(self,name,availabilities,speakerveto,isAllocated):
        self.name = name
        self.availabilities = availabilities
        self.speakerveto = speakerveto
        isAllocated = False
        
        
def importData():
    print("Please note the final allocation may take up to 10 minutes to compute.")
    global speakers
    speakers = []
    global times
    times = {}
    # CSV reading and parsing
    global csv
    csv = pd.read_csv("data.csv")
    csv.head()
    for index,row in csv.iterrows():
        if row[7] != "Adjudicating only": # MARK: Trial type
            avail = {}
            for i in range(14,29): # MARK: Range of trial slots
                avail[i-13] = preferencedict[row[i]] # MARK: Subtraction
            speakers.append(person(row[3],avail,vetodict[row[13]],False)) # MARK: Details

    # Calculate how many timeslots are required
    reqd = int(np.floor(len(speakers)/6))
    for key,value in alltimeslots.iteritems():
        if key <= reqd:
            times[key] = value
    print("A minimum of {} debates is required to distribute {} speakers.".format(reqd,len(speakers)))
    
    '''If the allocator produces an infeasible result there's a good chance it needs more timeslots.
    Manually override times with a higher number of slots if required'''
    
    for t in range(1,reqd):
        times[t] = alltimeslots[t]

    # Form the feasible team set
    global ftset
    global ftsample
    ftset = {}
    ftsample = {}
    totalteams = len(speakers)**3
    index = 1
    print("Forming Feasible Team Set...")
    for speaker1 in speakers:
        for speaker2 in speakers:
            for speaker3 in speakers:
                if speaker1 != speaker2 and speaker1 != speaker3 and speaker2 != speaker3:
                    if speaker1.speakerveto != 1 and speaker2.speakerveto != 2 and speaker3.speakerveto != 3:
                        print("Constructing team {} of {}...".format(index,totalteams))
                        ftset[index] = [speaker1,speaker2,speaker3]
                        index += 1
    
    randomkeys = random.sample(ftset.keys(), len(ftset)/1) # Vary so that a smaller subset is used for the fts
    for k in randomkeys:
        ftsample[k] = ftset[k]
    
    # Costs
    global costs
    costs = {}
    totalcosts = len(ftsample)*len(times)
    print("Calculating costs...")
    index2 = 1
    for key,team in ftsample.iteritems():
        for slot in times.keys():
            costs[key,slot] = 0
            index2 += 1
            print("Calculating cost {} of {}...".format(index2,totalcosts))
    
        # Time preferences
        '''Triallists are made aware that they may be called during "unavailable",
        so an 'unavailable' does not make the cost infinitely high, it just incurs
        a high cost.
        
        As slots become less desirable, the cost increases exponentially rather than
        linearly'''
    
        for speaker in team:
            for slot in times.keys():
                if speaker.availabilities[slot] == 4:
                    cost = grb.GRB.INFINITY
                else:
                    mag = speaker.availabilities[slot]*100
                    exp = mag**2
                    costs[key,slot] += exp
    
def allocate():
    # Optimisation
    a = grb.Model("2019 Easters Trial Allocator")
    x = {}
    for key,value in costs.iteritems():
        x[key] = a.addVar(vtype = grb.GRB.BINARY, obj = value, name = "x_{}".format(key))
        
    # Exactly 2 teams to each timeslot
    for slot in times.keys():
        a.addConstr(sum(x[team,slot] for team in ftsample.keys()) == 2)
        
    # Each team to no more than 1 timeslot
    for key,team in ftsample.iteritems():
        a.addConstr(sum(x[key,slot] for slot in times.keys()) <= 1)

    thirdvetoes = []
    for s in speakers:
        affectedTeams = []
        for key,team in ftsample.iteritems():
            if s in team:
                affectedTeams.append(key)
                
        # Each speaker to no more than 1 debate in 1 timeslot
        '''Can be 0 debates (ie. unallocated) and then appended
        as alternate 3rds'''
        a.addConstr(sum(x[team,slot] for team in affectedTeams for slot in times.keys()) <= 1)
        
        if s.speakerveto == 3:
            thirdvetoes.append(s)
            
    # Speakers who veto 3rd must be in exactly 1 timeslot
    '''3rd vetoes cannot be unallocated and then tacked on as
    alternate 3rds, so they must be allocated in a debate.'''
    for speaker in thirdvetoes:
        affectedTeams2 = []
        for key,team in ftsample.iteritems():
            if speaker in team:
                affectedTeams2.append(key)
        a.addConstr(sum(x[team,slot] for team in affectedTeams2 for slot in times.keys()) == 1)
    
    a.modelSense = grb.GRB.MINIMIZE
    a.optimize()
    
    unallocated = []
    unallocatednames = []
    print(div)
    print("USU EASTERS TRIALS 2019 - DEBATE ALLOCATION")
    print("Speakers in each team are listed in speaking order.")
    print("Sides for each debate should be determined randomly.")
    print(div)
    for key,value in costs.iteritems():
        if x[key].x != 0:
            spk = []
            for s in ftsample[key[0]]:
                spk.append(s.name)
            print("Team {} {} at {}".format(key[0],spk,times[key[1]]))
            for speaker in ftsample[key[0]]:
                speaker.isAllocated = True
    for speaker in speakers:
        if speaker.isAllocated == False:
            unallocated.append(speaker)
            unallocatednames.append(speaker.name)
    print("Total Cost: {}".format(a.objVal))
    print(div)
    
    j = ", "
    print("Unallocated Speakers: {}".format(j.join(unallocatednames)))
    print(div)
    report(unallocated)

def report(speakers):
    for speaker in speakers:
        if speaker not in speakers:
            print("Speaker {} does not exist".format(speaker.name))
        else:
            vetoString= "{} {}.".format(speaker.name, vetodictinv[speaker.speakerveto])

            print("Report for {}".format(speaker.name))
            print(vetoString)
            print("{}'s availability is as follows:".format(speaker.name))
            for slot,availability in speaker.availabilities.iteritems():
                try:
                    # TODO
                    pass
                    #print("{}: {}".format(times[slot],availability))
                except:
                    pass
        print(div)

# %%
importData()
# Out:
# Please note the final allocation may take up to 10 minutes to compute.
# A minimum of 3 debates is required to distribute 18 speakers.
# Forming Feasible Team Set...
# Constructing team 1 of 5832...
# Constructing team 2 of 5832...
# Constructing team 3 of 5832...
# Constructing team 4 of 5832...
# Constructing team 5 of 5832...
# Constructing team 6 of 5832...
# Constructing team 7 of 5832...
# Constructing team 8 of 5832...
# Constructing team 9 of 5832...
# Constructing team 10 of 5832...
# Constructing team 11 of 5832...
# Constructing team 12 of 5832...
# Constructing team 13 of 5832...
# Constructing team 14 of 5832...
# Constructing team 15 of 5832...
# Constructing team 16 of 5832...
# Constructing team 17 of 5832...
# Constructing team 18 of 5832...
# Constructing team 19 of 5832...
# Constructing team 20 of 5832...
# Constructing team 21 of 5832...
# Constructing team 22 of 5832...
# Constructing team 23 of 5832...
# Constructing team 24 of 5832...
# Constructing team 25 of 5832...
# Constructing team 26 of 5832...
# Constructing team 27 of 5832...
# Constructing team 28 of 5832...
# Constructing team 29 of 5832...
# Constructing team 30 of 5832...
# Constructing team 31 of 5832...
# Constructing team 32 of 5832...
# Constructing team 33 of 5832...
# Constructing team 34 of 5832...
# Constructing team 35 of 5832...
# Constructing team 36 of 5832...
# Constructing team 37 of 5832...
# Constructing team 38 of 5832...
# Constructing team 39 of 5832...
# Constructing team 40 of 5832...
# Constructing team 41 of 5832...
# Constructing team 42 of 5832...
# Constructing team 43 of 5832...
# Constructing team 44 of 5832...
# Constructing team 45 of 5832...
# Constructing team 46 of 5832...
# Constructing team 47 of 5832...
# Constructing team 48 of 5832...
# Constructing team 49 of 5832...
# Constructing team 50 of 5832...
# Constructing team 51 of 5832...
# Constructing team 52 of 5832...
# Constructing team 53 of 5832...
# Constructing team 54 of 5832...
# Constructing team 55 of 5832...
# Constructing team 56 of 5832...
# Constructing team 57 of 5832...
# Constructing team 58 of 5832...
# Constructing team 59 of 5832...
# Constructing team 60 of 5832...
# Constructing team 61 of 5832...
# Constructing team 62 of 5832...
# Constructing team 63 of 5832...
# Constructing team 64 of 5832...
# Constructing team 65 of 5832...
# Constructing team 66 of 5832...
# Constructing team 67 of 5832...
# Constructing team 68 of 5832...
# Constructing team 69 of 5832...
# Constructing team 70 of 5832...
# Constructing team 71 of 5832...
# Constructing team 72 of 5832...
# Constructing team 73 of 5832...
# Constructing team 74 of 5832...
# Constructing team 75 of 5832...
# Constructing team 76 of 5832...
# Constructing team 77 of 5832...
# Constructing team 78 of 5832...
# Constructing team 79 of 5832...
# Constructing team 80 of 5832...
# Constructing team 81 of 5832...
# Constructing team 82 of 5832...
# Constructing team 83 of 5832...
# Constructing team 84 of 5832...
# Constructing team 85 of 5832...
# Constructing team 86 of 5832...
# Constructing team 87 of 5832...
# Constructing team 88 of 5832...
# Constructing team 89 of 5832...
# Constructing team 90 of 5832...
# Constructing team 91 of 5832...
# Constructing team 92 of 5832...
# Constructing team 93 of 5832...
# Constructing team 94 of 5832...
# Constructing team 95 of 5832...
# Constructing team 96 of 5832...
# Constructing team 97 of 5832...
# Constructing team 98 of 5832...
# Constructing team 1418 of 5832...
# Constructing team 1419 of 5832...
# Constructing team 1420 of 5832...
# Constructing team 1421 of 5832...
# Constructing team 1422 of 5832...
# Constructing team 1423 of 5832...
# Constructing team 1424 of 5832...
# Constructing team 1425 of 5832...
# Constructing team 1426 of 5832...
# Constructing team 1427 of 5832...
# Constructing team 1428 of 5832...
# Constructing team 1429 of 5832...
# Constructing team 1430 of 5832...
# Constructing team 1431 of 5832...
# Constructing team 1432 of 5832...
# Constructing team 1433 of 5832...
# Constructing team 1434 of 5832...
# Constructing team 1435 of 5832...
# Constructing team 1436 of 5832...
# Constructing team 1437 of 5832...
# Constructing team 1438 of 5832...
# Constructing team 1439 of 5832...
# ...
# Calculating cost 6292 of 6774...
# Calculating cost 6293 of 6774...
# Calculating cost 6294 of 6774...
# Calculating cost 6295 of 6774...
# Calculating cost 6296 of 6774...
# Calculating cost 6297 of 6774...
# Calculating cost 6298 of 6774...
# Calculating cost 6299 of 6774...
# Calculating cost 6300 of 6774...
# Calculating cost 6301 of 6774...
# Calculating cost 6302 of 6774...
# Calculating cost 6303 of 6774...
# Calculating cost 6304 of 6774...
# Calculating cost 6305 of 6774...
# Calculating cost 6306 of 6774...
# Calculating cost 6307 of 6774...
# Calculating cost 6308 of 6774...
# Calculating cost 6309 of 6774...
# Calculating cost 6310 of 6774...
# Calculating cost 6311 of 6774...
# Calculating cost 6312 of 6774...
# Calculating cost 6313 of 6774...
# Calculating cost 6314 of 6774...
# Calculating cost 6315 of 6774...
# Calculating cost 6316 of 6774...
# Calculating cost 6317 of 6774...
# Calculating cost 6318 of 6774...
# Calculating cost 6319 of 6774...
# Calculating cost 6320 of 6774...
# Calculating cost 6321 of 6774...
# Calculating cost 6322 of 6774...
# Calculating cost 6323 of 6774...
# Calculating cost 6324 of 6774...
# Calculating cost 6325 of 6774...
# Calculating cost 6326 of 6774...
# Calculating cost 6327 of 6774...
# Calculating cost 6328 of 6774...
# Calculating cost 6329 of 6774...
# Calculating cost 6330 of 6774...
# Calculating cost 6331 of 6774...
# Calculating cost 6332 of 6774...
# Calculating cost 6333 of 6774...
# Calculating cost 6334 of 6774...
# Calculating cost 6335 of 6774...
# Calculating cost 6336 of 6774...
# Calculating cost 6337 of 6774...
# Calculating cost 6338 of 6774...
# Calculating cost 6339 of 6774...
# Calculating cost 6340 of 6774...
# Calculating cost 6341 of 6774...
# Calculating cost 6342 of 6774...
# Calculating cost 6343 of 6774...
# Calculating cost 6344 of 6774...
# Calculating cost 6345 of 6774...
# Calculating cost 6346 of 6774...
# Calculating cost 6347 of 6774...
# Calculating cost 6348 of 6774...
# Calculating cost 6349 of 6774...
# Calculating cost 6350 of 6774...
# Calculating cost 6351 of 6774...
# Calculating cost 6352 of 6774...
# Calculating cost 6353 of 6774...
# Calculating cost 6354 of 6774...
# Calculating cost 6355 of 6774...
# Calculating cost 6356 of 6774...
# Calculating cost 6357 of 6774...
# Calculating cost 6358 of 6774...
# Calculating cost 6359 of 6774...
# Calculating cost 6360 of 6774...
# Calculating cost 6361 of 6774...
# Calculating cost 6362 of 6774...
# Calculating cost 6363 of 6774...
# Calculating cost 6364 of 6774...
# Calculating cost 6365 of 6774...
# Calculating cost 6366 of 6774...
# Calculating cost 6367 of 6774...
# Calculating cost 6368 of 6774...
# Calculating cost 6369 of 6774...
# Calculating cost 6370 of 6774...
# Calculating cost 6371 of 6774...
# Calculating cost 6372 of 6774...
# Calculating cost 6373 of 6774...
# Calculating cost 6374 of 6774...
# Calculating cost 6375 of 6774...
# Calculating cost 6376 of 6774...
# Calculating cost 6377 of 6774...
# Calculating cost 6378 of 6774...
# Calculating cost 6379 of 6774...
# Calculating cost 6380 of 6774...
# Calculating cost 6381 of 6774...
# Calculating cost 6382 of 6774...
# Calculating cost 6383 of 6774...
# Calculating cost 6384 of 6774...
# Calculating cost 6385 of 6774...
# Calculating cost 6386 of 6774...
# Calculating cost 6387 of 6774...
# Calculating cost 6388 of 6774...
# Calculating cost 6389 of 6774...
# Calculating cost 6390 of 6774...
# Calculating cost 6391 of 6774...
# Calculating cost 6392 of 6774...
# Calculating cost 6393 of 6774...
# Calculating cost 6394 of 6774...
# Calculating cost 6395 of 6774...
# Calculating cost 6396 of 6774...
# Calculating cost 6397 of 6774...
# Calculating cost 6398 of 6774...
# Calculating cost 6399 of 6774...
# Calculating cost 6400 of 6774...
# Calculating cost 6401 of 6774...
# Calculating cost 6402 of 6774...
# Calculating cost 6403 of 6774...
# Calculating cost 6404 of 6774...
# Calculating cost 6405 of 6774...
# Calculating cost 6406 of 6774...
# Calculating cost 6407 of 6774...
# Calculating cost 6408 of 6774...
# Calculating cost 6409 of 6774...
# Calculating cost 6410 of 6774...
# Calculating cost 6411 of 6774...
# Calculating cost 6412 of 6774...
# Calculating cost 6413 of 6774...
# Calculating cost 6414 of 6774...
# Calculating cost 6415 of 6774...
# Calculating cost 6416 of 6774...
# Calculating cost 6417 of 6774...
# Calculating cost 6418 of 6774...
# Calculating cost 6419 of 6774...
# Calculating cost 6420 of 6774...
# Calculating cost 6421 of 6774...
# Calculating cost 6422 of 6774...
# Calculating cost 6423 of 6774...
# Calculating cost 6424 of 6774...
# Calculating cost 6425 of 6774...
# Calculating cost 6426 of 6774...
# Calculating cost 6427 of 6774...
# Calculating cost 6428 of 6774...
# Calculating cost 6429 of 6774...
# Calculating cost 6430 of 6774...
# Calculating cost 6431 of 6774...
# Calculating cost 6432 of 6774...
# Calculating cost 6433 of 6774...
# Calculating cost 6434 of 6774...
# Calculating cost 6435 of 6774...
# Calculating cost 6436 of 6774...
# Calculating cost 6437 of 6774...
# Calculating cost 6438 of 6774...
# Calculating cost 6439 of 6774...
# Calculating cost 6440 of 6774...
# Calculating cost 6441 of 6774...
# Calculating cost 6442 of 6774...
# Calculating cost 6443 of 6774...
# Calculating cost 6444 of 6774...
# Calculating cost 6445 of 6774...
# Calculating cost 6446 of 6774...
# Calculating cost 6447 of 6774...
# Calculating cost 6448 of 6774...
# Calculating cost 6449 of 6774...
# Calculating cost 6450 of 6774...
# Calculating cost 6451 of 6774...
# Calculating cost 6452 of 6774...
# Calculating cost 6453 of 6774...
# Calculating cost 6454 of 6774...
# Calculating cost 6455 of 6774...
# Calculating cost 6456 of 6774...
# Calculating cost 6457 of 6774...
# Calculating cost 6458 of 6774...
# Calculating cost 6459 of 6774...
# Calculating cost 6460 of 6774...
# Calculating cost 6461 of 6774...
# Calculating cost 6462 of 6774...
# Calculating cost 6463 of 6774...
# Calculating cost 6464 of 6774...
# Calculating cost 6465 of 6774...
# Calculating cost 6466 of 6774...
# Calculating cost 6467 of 6774...
# Calculating cost 6468 of 6774...
# Calculating cost 6469 of 6774...
# Calculating cost 6470 of 6774...
# Calculating cost 6471 of 6774...
# Calculating cost 6472 of 6774...
# Calculating cost 6473 of 6774...
# Calculating cost 6474 of 6774...
# Calculating cost 6475 of 6774...
# Calculating cost 6476 of 6774...
# Calculating cost 6477 of 6774...
# Calculating cost 6478 of 6774...
# Calculating cost 6479 of 6774...
# Calculating cost 6480 of 6774...
# Calculating cost 6481 of 6774...
# Calculating cost 6482 of 6774...
# Calculating cost 6483 of 6774...
# Calculating cost 6484 of 6774...
# Calculating cost 6485 of 6774...
# Calculating cost 6486 of 6774...
# Calculating cost 6487 of 6774...
# Calculating cost 6488 of 6774...
# Calculating cost 6489 of 6774...
# Calculating cost 6490 of 6774...
# Calculating cost 6491 of 6774...
# Calculating cost 6492 of 6774...
# Calculating cost 6493 of 6774...
# Calculating cost 6494 of 6774...
# Calculating cost 6495 of 6774...
# Calculating cost 6496 of 6774...
# Calculating cost 6497 of 6774...
# Calculating cost 6498 of 6774...
# Calculating cost 6499 of 6774...
# Calculating cost 6500 of 6774...
# Calculating cost 6501 of 6774...
# Calculating cost 6502 of 6774...
# Calculating cost 6503 of 6774...
# Calculating cost 6504 of 6774...
# Calculating cost 6505 of 6774...
# Calculating cost 6506 of 6774...
# Calculating cost 6507 of 6774...
# Calculating cost 6508 of 6774...
# Calculating cost 6509 of 6774...
# Calculating cost 6510 of 6774...
# Calculating cost 6511 of 6774...
# Calculating cost 6512 of 6774...
# Calculating cost 6513 of 6774...
# Calculating cost 6514 of 6774...
# Calculating cost 6515 of 6774...
# Calculating cost 6516 of 6774...
# Calculating cost 6517 of 6774...
# Calculating cost 6518 of 6774...
# Calculating cost 6519 of 6774...
# Calculating cost 6520 of 6774...
# Calculating cost 6521 of 6774...
# Calculating cost 6522 of 6774...
# Calculating cost 6523 of 6774...
# Calculating cost 6524 of 6774...
# Calculating cost 6525 of 6774...
# Calculating cost 6526 of 6774...
# Calculating cost 6527 of 6774...
# Calculating cost 6528 of 6774...
# Calculating cost 6529 of 6774...
# Calculating cost 6530 of 6774...
# Calculating cost 6531 of 6774...
# Calculating cost 6532 of 6774...
# Calculating cost 6533 of 6774...
# Calculating cost 6534 of 6774...
# Calculating cost 6535 of 6774...
# Calculating cost 6536 of 6774...
# Calculating cost 6537 of 6774...
# Calculating cost 6538 of 6774...
# Calculating cost 6539 of 6774...
# Calculating cost 6540 of 6774...
# Calculating cost 6541 of 6774...
# Calculating cost 6542 of 6774...
# Calculating cost 6543 of 6774...
# Calculating cost 6544 of 6774...
# Calculating cost 6545 of 6774...
# Calculating cost 6546 of 6774...
# Calculating cost 6547 of 6774...
# Calculating cost 6548 of 6774...
# Calculating cost 6549 of 6774...
# Calculating cost 6550 of 6774...
# Calculating cost 6551 of 6774...
# Calculating cost 6552 of 6774...
# Calculating cost 6553 of 6774...
# Calculating cost 6554 of 6774...
# Calculating cost 6555 of 6774...
# Calculating cost 6556 of 6774...
# Calculating cost 6557 of 6774...
# Calculating cost 6558 of 6774...
# Calculating cost 6559 of 6774...
# Calculating cost 6560 of 6774...
# Calculating cost 6561 of 6774...
# Calculating cost 6562 of 6774...
# Calculating cost 6563 of 6774...
# Calculating cost 6564 of 6774...
# Calculating cost 6565 of 6774...
# Calculating cost 6566 of 6774...
# Calculating cost 6567 of 6774...
# Calculating cost 6568 of 6774...
# Calculating cost 6569 of 6774...
# Calculating cost 6570 of 6774...
# Calculating cost 6571 of 6774...
# Calculating cost 6572 of 6774...
# Calculating cost 6573 of 6774...
# Calculating cost 6574 of 6774...
# Calculating cost 6575 of 6774...
# Calculating cost 6576 of 6774...
# Calculating cost 6577 of 6774...
# Calculating cost 6578 of 6774...
# Calculating cost 6579 of 6774...
# Calculating cost 6580 of 6774...
# Calculating cost 6581 of 6774...
# Calculating cost 6582 of 6774...
# Calculating cost 6583 of 6774...
# Calculating cost 6584 of 6774...
# Calculating cost 6585 of 6774...
# Calculating cost 6586 of 6774...
# Calculating cost 6587 of 6774...
# Calculating cost 6588 of 6774...
# Calculating cost 6589 of 6774...
# Calculating cost 6590 of 6774...
# Calculating cost 6591 of 6774...
# Calculating cost 6592 of 6774...
# Calculating cost 6593 of 6774...
# Calculating cost 6594 of 6774...
# Calculating cost 6595 of 6774...
# Calculating cost 6596 of 6774...
# Calculating cost 6597 of 6774...
# Calculating cost 6598 of 6774...
# Calculating cost 6599 of 6774...
# Calculating cost 6600 of 6774...
# Calculating cost 6601 of 6774...
# Calculating cost 6602 of 6774...
# Calculating cost 6603 of 6774...
# Calculating cost 6604 of 6774...
# Calculating cost 6605 of 6774...
# Calculating cost 6606 of 6774...
# Calculating cost 6607 of 6774...
# Calculating cost 6608 of 6774...
# Calculating cost 6609 of 6774...
# Calculating cost 6610 of 6774...
# Calculating cost 6611 of 6774...
# Calculating cost 6612 of 6774...
# Calculating cost 6613 of 6774...
# Calculating cost 6614 of 6774...
# Calculating cost 6615 of 6774...
# Calculating cost 6616 of 6774...
# Calculating cost 6617 of 6774...
# Calculating cost 6618 of 6774...
# Calculating cost 6619 of 6774...
# Calculating cost 6620 of 6774...
# Calculating cost 6621 of 6774...
# Calculating cost 6622 of 6774...
# Calculating cost 6623 of 6774...
# Calculating cost 6624 of 6774...
# Calculating cost 6625 of 6774...
# Calculating cost 6626 of 6774...
# Calculating cost 6627 of 6774...
# Calculating cost 6628 of 6774...
# Calculating cost 6629 of 6774...
# Calculating cost 6630 of 6774...
# Calculating cost 6631 of 6774...
# Calculating cost 6632 of 6774...
# Calculating cost 6633 of 6774...
# Calculating cost 6634 of 6774...
# Calculating cost 6635 of 6774...
# Calculating cost 6636 of 6774...
# Calculating cost 6637 of 6774...
# Calculating cost 6638 of 6774...
# Calculating cost 6639 of 6774...
# Calculating cost 6640 of 6774...
# Calculating cost 6641 of 6774...
# Calculating cost 6642 of 6774...
# Calculating cost 6643 of 6774...
# Calculating cost 6644 of 6774...
# Calculating cost 6645 of 6774...
# Calculating cost 6646 of 6774...
# Calculating cost 6647 of 6774...
# Calculating cost 6648 of 6774...
# Calculating cost 6649 of 6774...
# Calculating cost 6650 of 6774...
# Calculating cost 6651 of 6774...
# Calculating cost 6652 of 6774...
# Calculating cost 6653 of 6774...
# Calculating cost 6654 of 6774...
# Calculating cost 6655 of 6774...
# Calculating cost 6656 of 6774...
# Calculating cost 6657 of 6774...
# Calculating cost 6658 of 6774...
# Calculating cost 6659 of 6774...
# Calculating cost 6660 of 6774...
# Calculating cost 6661 of 6774...
# Calculating cost 6662 of 6774...
# Calculating cost 6663 of 6774...
# Calculating cost 6664 of 6774...
# Calculating cost 6665 of 6774...
# Calculating cost 6666 of 6774...
# Calculating cost 6667 of 6774...
# Calculating cost 6668 of 6774...
# Calculating cost 6669 of 6774...
# Calculating cost 6670 of 6774...
# Calculating cost 6671 of 6774...
# Calculating cost 6672 of 6774...
# Calculating cost 6673 of 6774...
# Calculating cost 6674 of 6774...
# Calculating cost 6675 of 6774...
# Calculating cost 6676 of 6774...
# Calculating cost 6677 of 6774...
# Calculating cost 6678 of 6774...
# Calculating cost 6679 of 6774...
# Calculating cost 6680 of 6774...
# Calculating cost 6681 of 6774...
# Calculating cost 6682 of 6774...
# Calculating cost 6683 of 6774...
# Calculating cost 6684 of 6774...
# Calculating cost 6685 of 6774...
# Calculating cost 6686 of 6774...
# Calculating cost 6687 of 6774...
# Calculating cost 6688 of 6774...
# Calculating cost 6689 of 6774...
# Calculating cost 6690 of 6774...
# Calculating cost 6691 of 6774...
# Calculating cost 6692 of 6774...
# Calculating cost 6693 of 6774...
# Calculating cost 6694 of 6774...
# Calculating cost 6695 of 6774...
# Calculating cost 6696 of 6774...
# Calculating cost 6697 of 6774...
# Calculating cost 6698 of 6774...
# Calculating cost 6699 of 6774...
# Calculating cost 6700 of 6774...
# Calculating cost 6701 of 6774...
# Calculating cost 6702 of 6774...
# Calculating cost 6703 of 6774...
# Calculating cost 6704 of 6774...
# Calculating cost 6705 of 6774...
# Calculating cost 6706 of 6774...
# Calculating cost 6707 of 6774...
# Calculating cost 6708 of 6774...
# Calculating cost 6709 of 6774...
# Calculating cost 6710 of 6774...
# Calculating cost 6711 of 6774...
# Calculating cost 6712 of 6774...
# Calculating cost 6713 of 6774...
# Calculating cost 6714 of 6774...
# Calculating cost 6715 of 6774...
# Calculating cost 6716 of 6774...
# Calculating cost 6717 of 6774...
# Calculating cost 6718 of 6774...
# Calculating cost 6719 of 6774...
# Calculating cost 6720 of 6774...
# Calculating cost 6721 of 6774...
# Calculating cost 6722 of 6774...
# Calculating cost 6723 of 6774...
# Calculating cost 6724 of 6774...
# Calculating cost 6725 of 6774...
# Calculating cost 6726 of 6774...
# Calculating cost 6727 of 6774...
# Calculating cost 6728 of 6774...
# Calculating cost 6729 of 6774...
# Calculating cost 6730 of 6774...
# Calculating cost 6731 of 6774...
# Calculating cost 6732 of 6774...
# Calculating cost 6733 of 6774...
# Calculating cost 6734 of 6774...
# Calculating cost 6735 of 6774...
# Calculating cost 6736 of 6774...
# Calculating cost 6737 of 6774...
# Calculating cost 6738 of 6774...
# Calculating cost 6739 of 6774...
# Calculating cost 6740 of 6774...
# Calculating cost 6741 of 6774...
# Calculating cost 6742 of 6774...
# Calculating cost 6743 of 6774...
# Calculating cost 6744 of 6774...
# Calculating cost 6745 of 6774...
# Calculating cost 6746 of 6774...
# Calculating cost 6747 of 6774...
# Calculating cost 6748 of 6774...
# Calculating cost 6749 of 6774...
# Calculating cost 6750 of 6774...
# Calculating cost 6751 of 6774...
# Calculating cost 6752 of 6774...
# Calculating cost 6753 of 6774...
# Calculating cost 6754 of 6774...
# Calculating cost 6755 of 6774...
# Calculating cost 6756 of 6774...
# Calculating cost 6757 of 6774...
# Calculating cost 6758 of 6774...
# Calculating cost 6759 of 6774...
# Calculating cost 6760 of 6774...
# Calculating cost 6761 of 6774...
# Calculating cost 6762 of 6774...
# Calculating cost 6763 of 6774...
# Calculating cost 6764 of 6774...
# Calculating cost 6765 of 6774...
# Calculating cost 6766 of 6774...
# Calculating cost 6767 of 6774...
# Calculating cost 6768 of 6774...
# Calculating cost 6769 of 6774...
# Calculating cost 6770 of 6774...
# Calculating cost 6771 of 6774...
# Calculating cost 6772 of 6774...
# Calculating cost 6773 of 6774...
# Calculating cost 6774 of 6774...
# Calculating cost 6775 of 6774...

# %%
allocate()
# Out:
# Optimize a model with 2285 rows, 6774 columns and 39594 nonzeros
# Variable types: 0 continuous, 6774 integer (6774 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [1e+04, 3e+05]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 2e+00]
# Found heuristic solution: objective 370000.00000
# Presolve removed 2264 rows and 4416 columns
# Presolve time: 0.07s
# Presolved: 21 rows, 2358 columns, 9432 nonzeros
# Found heuristic solution: objective 280000.00000
# Variable types: 0 continuous, 2358 integer (2358 binary)
#
# Root relaxation: objective 9.000000e+04, 46 iterations, 0.00 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 90000.0000    0   17 280000.000 90000.0000  67.9%     -    0s
# H    0     0                    90000.000000 90000.0000  0.00%     -    0s
#
# Explored 1 nodes (113 simplex iterations) in 0.16 seconds
# Thread count was 4 (of 4 available processors)
#
# Solution count 2: 90000 280000
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 9.000000000000e+04, best bound 9.000000000000e+04, gap 0.0000%
# -----
# USU EASTERS TRIALS 2019 - DEBATE ALLOCATION
# Speakers in each team are listed in speaking order.
# Sides for each debate should be determined randomly.
# -----
# Team 450 ['Sophia Bleakley', 'Anna Burton', 'Yijing (Grace) Wong'] at 9:30am
# Team 1830 ['Kireth Sandhu', 'Vivian Jiahui Zhu', 'Sofia Mendes'] at 8:45am
# Team 33 ['Shanshan Guo', 'Sarah Korte', 'Ibrahim Taha'] at 8:00am
# Team 951 ["Daniel O'Dea", 'Nick Rice', 'Damian Young'] at 8:45am
# Team 2243 ['Arin Tornyi-Aydin', 'Joshua Chahoud', 'Alex He'] at 9:30am
# Team 283 ['Kush Pakki', 'Emily Kim', 'Sweeney Hughes'] at 8:00am
# Total Cost: 90000.0
# -----
# Unallocated Speakers:
# -----
